# %% [markdown]
# # Steps
# # 1 . Preprocess + EDA + Features selection
# # 2.  Extract input and output cols
# # 3.  Scale the values
# # 4.  Train test splits
# # 5.  Train the Model
# # 6. Evaluate the model/ model selection
# # 7.  Deploy the model

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/Users/rishidwivedi/Downloads/placement.csv')
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %% [markdown]
# # PREPROCESSING

# %%
df = df.iloc[:,1:] #: ISKA MTLB SARE ROWS CHIE 1: ISKE MTLB COLUMN ONEONWARDS
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['iq'])

# %% [markdown]
# EDA

# %%
plt.scatter(df['cgpa'], df['iq'], c=df['placement'])

# %%
x = df.iloc[:,0:2] #row poora chie column 2 tk basss
y = df.iloc[:,-1]
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %% [markdown]
# TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split
train_test_split(x,y,test_size=0.1)
# x independent  variable y dependent variable
# test_size me dete hai size = 0.1 mtlb x and y me se 10% data out of 100 , 10 rows training baki testing mein
# Out:
# [    cgpa     iq
#  97   6.7  182.0
#  14   6.1  103.0
#  12   5.4  139.0
#  2    5.3  121.0
#  94   4.7   52.0
#  ..   ...    ...
#  57   6.5  130.0
#  62   6.0  102.0
#  10   6.0   45.0
#  31   3.9  109.0
#  39   4.6  146.0
#
#  [90 rows x 2 columns],
#      cgpa     iq
#  51   4.8  141.0
#  68   4.0   75.0
#  36   5.7  140.0
#  11   6.9  138.0
#  46   5.3  114.0
#  27   6.0  124.0
#  58   8.0   79.0
#  77   7.3   50.0
#  78   6.1   81.0
#  40   4.9  134.0,
#  97    1
#  14    0
#  12    0
#  2     0
#  94    0
#       ..
#  57    1
#  62    0
#  10    1
#  31    0
#  39    0
#  Name: placement, Length: 90, dtype: int64,
#  51    0
#  68    0
#  36    0
#  11    1
#  46    0
#  27    1
#  58    1
#  77    1
#  78    0
#  40    0
#  Name: placement, dtype: int64]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,y_train,y_test =train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 41   5.4  114.0
# 28   5.2   90.0
# 32   7.0  139.0
# 94   4.7   52.0
# 3    7.4  132.0
# ..   ...    ...
# 27   6.0  124.0
# 18   4.0  100.0
# 64   7.0   64.0
# 86   5.1  128.0
# 69   8.5  120.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 41    0
# 28    0
# 32    1
# 94    0
# 3     1
#      ..
# 27    1
# 18    0
# 64    1
# 86    0
# 69    1
# Name: placement, Length: 90, dtype: int64

# %%
x_train
# Out:
#     cgpa     iq
# 41   5.4  114.0
# 28   5.2   90.0
# 32   7.0  139.0
# 94   4.7   52.0
# 3    7.4  132.0
# ..   ...    ...
# 27   6.0  124.0
# 18   4.0  100.0
# 64   7.0   64.0
# 86   5.1  128.0
# 69   8.5  120.0
#
# [90 rows x 2 columns]

# %% [markdown]
# scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_train
# Out:
# array([[-0.44879019, -0.25733491],
#        [-0.62633357, -0.85565933],
#        [ 0.97155679,  0.36591971],
#        [-1.070192  , -1.80300635],
#        [ 1.32664354,  0.19140842],
#        [-0.00493176, -0.45677638],
#        [-0.89264862,  1.78694023],
#        [ 1.68173028, -0.25733491],
#        [ 0.79401342, -0.85565933],
#        [ 0.52769836, -2.17695912],
#        [ 0.17261161, -0.53156694],
#        [-0.53756188, -0.25733491],
#        [ 0.08383993,  0.61522155],
#        [-0.18247513,  0.39084989],
#        [ 0.35015499, -0.53156694],
#        [-1.33650706, -2.05230819],
#        [-1.070192  , -0.08282361],
#        [-0.62633357, -0.35705564],
#        [-0.71510525,  1.28833654],
#        [-1.33650706,  0.61522155],
#        [-0.44879019,  0.26619897],
#        [ 0.17261161, -1.47891395],
#        [ 0.08383993, -0.55649712],
#        [ 1.94804534,  0.61522155],
#        [-0.18247513,  0.46564045],
#        [-0.71510525, -1.45398376],
#        [ 1.50418691,  0.09168768],
# ...

# %%
x_test = scaler.transform(x_test)
x_test
# Out:
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.14/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-6.11368462, -3.07160808],
#        [-4.53760216, -3.10019772],
#        [-4.14358154, -3.09149653],
#        [-5.64085988, -3.11014195],
#        [-3.59195268, -3.12754434],
#        [-4.77401453, -3.0772017 ],
#        [-3.90716917, -3.1213292 ],
#        [-4.53760216, -3.08901047],
#        [-4.14358154, -3.10454832],
#        [-4.30118979, -3.14681128]])

# %%
# model train kr rhe logistic regression use krke

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression() #object bnae hh clf k pass power hh un function ko acces krne ka jo logistic regression class k ander h

# %%
#model training ke lie krte h fit() ka use 
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 75    0
# 0     1
# 61    1
# 81    0
# 58    1
# 38    1
# 42    1
# 43    1
# 72    1
# 5     1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.2

# %% [markdown]
# How to plot the decision boundary
# ....mtlb machine learning model ne ky patter notice kie data me agar ussa visualise krna hai to ussa ham (decison boundry ka use krke visualise kr skte hh)

# %%
pip install mlxtend.  # yha se ham code uthaye hh
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.2 MB/s  0:00:01 eta 0:00:010m
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values,clf=clf, legend=2)
# Out:
# <Axes: >

# %% [markdown]
# yaha se model koo uthana hote h ab next step m

# %%
import pickle # python me everything is an object to ye pickle sare object ko utha kr ek file me kr deta hai aor
# uss file ko ham utha kr or envoronment m use kr skte h

# %%
pickle.dump(clf,open('model.pk1','wb'))
